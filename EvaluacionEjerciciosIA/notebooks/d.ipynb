# %%
import torch
print(torch.__version__)
# Out:
# 2.8.0+cu126

# %%
import torch
from torch.optim import lr_scheduler

print(torch.__version__)
print(lr_scheduler.ReduceLROnPlateau.__init__.__code__.co_varnames)
# Out:
# 2.8.0+cu126
# ('self', 'optimizer', 'mode', 'factor', 'patience', 'threshold', 'threshold_mode', 'cooldown', 'min_lr', 'eps')
